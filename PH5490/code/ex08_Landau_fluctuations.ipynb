# %% [markdown]
# # Landau theory
# > a phenomenological theory of phase transitions

# %%
import numpy as np
from numpy.random import rand
import matplotlib.pyplot as plt
from matplotlib.colors import LightSource

# %%
fig = plt.figure(num=None, figsize=(6, 6), dpi=256, facecolor='w', edgecolor='k')
ax = fig.add_subplot(projection='3d')

# Create the mesh in polar coordinates and compute corresponding Z.
r = np.linspace(0, 1.25, 50)
p = np.linspace(0, 2*np.pi, 50)
R, P = np.meshgrid(r, p)
Z = ((R**2 - 1)**2)

# Express the mesh in the cartesian system.
X, Y = R*np.cos(P), R*np.sin(P)




# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=plt.cm.RdBu)
fig.colorbar(surf, shrink=0.75, aspect=16, orientation='horizontal')

# %%
fig = plt.figure(num=None, figsize=(6, 6), dpi=256, facecolor='w', edgecolor='k')
ax = fig.add_subplot(projection='3d')

# Create the mesh in polar coordinates and compute corresponding Z.
r = np.linspace(0, 1.25, 50)
p = np.linspace(0, 2*np.pi, 50)
R, P = np.meshgrid(r, p)
Z = ((R**2 -1 )**2)

# Express the mesh in the cartesian system.
X, Y = R*np.cos(P), R*np.sin(P)




# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=plt.cm.RdBu)
fig.colorbar(surf, shrink=0.75, aspect=16, orientation='horizontal')
plt.axis('off')
# Out:
# (-1.429536138714644, 1.4321043977767234, -1.4315557784124435, 1.43155577841244
# 35, -0.020727582433366414, 1.0208311751517014)

# %% [markdown]
# #### Minimizing the free energy
#
# Minimising the free energy with respect to $m$, we get
#
# $$
# am + bm^3=0
# $$
#
# Thus, the solutions are:
#
# $$
# m=\pm\sqrt{\frac{-a}b},\qquad m=0
# $$
#
# The critical exponent is:
#
# $$
# m\propto (T_c-T)^{0.5}
# $$

# %%
fig = plt.figure(num=None, figsize=(6, 6), dpi=100, facecolor='w', edgecolor='k')
plt.rcParams.update({'font.size': 16}); plt.grid()

def orderparam(phib, w, m):
    return phib*np.tanh(m/w)

Nt=64
m = np.linspace(-16.5, 16.5, Nt)
phib = 1
w = 4

plt.plot(m, orderparam(phib, w, m), '-', lw=5, label='$T>T_c$')
plt.xlabel(r'$m$'); plt.ylim(-1.15, 1.15)
# plt.legend();
plt.axvspan(-w, w, alpha=0.25, color='red' )

# %% [markdown]
# ## Plotting the mean field solution

# %%
from sympy import *
x, y, z, a = symbols('x y z a')
init_printing(use_unicode=True)

# %%
diff(cos(x), x)
# Out:
# -sin(x)

# %%
diff(tanh(a*x), x)
# Out:
#   ⎛        2     ⎞
# a⋅⎝1 - tanh (a⋅x)⎠

# %% [markdown]
# $$
# \text{sech} ^2 (x) = 1 - \tanh^ x
# $$

# %%
diff(a*sech(a*x)**2, x)
# Out:
#     2               2
# -2⋅a ⋅tanh(a⋅x)⋅sech (a⋅x)

# %%
diff(diff(tanh(a*x), x),x)
# Out:
#     2 ⎛        2     ⎞
# -2⋅a ⋅⎝1 - tanh (a⋅x)⎠⋅tanh(a⋅x)

# %%
diff(diff(sinh(a*x), x),x)
# Out:
#  2
# a ⋅sinh(a⋅x)
