# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 12})

# %%
xx=1.42;  x = np.linspace(-xx,xx,128); 

AFa=4; plt.figure(figsize=(12, 4), dpi=80)

plt.subplot(121)
y = -AFa*(np.abs(x)**1.0);      plt.plot(x, y, color='tab:blue',lw=2, label=r'$n=1$')
y = -AFa*(np.abs(x)**1.5);      plt.plot(x, y, color='tab:pink',lw=2, label=r'$n=1.5$')
y = -AFa*(np.abs(x)**2.0);      plt.plot(x, y, color='tab:red',lw=2, label=r'$n=2$')
plt.grid(); plt.legend(loc='lower center', fontsize=12);  

plt.subplot(122)
y = AFa*(np.abs(x)**1.0);      plt.plot(x, y, color='tab:blue',lw=2, label=r'$n=1$')
y = AFa*(np.abs(x)**1.5);      plt.plot(x, y, color='tab:pink',lw=2, label=r'$n=1.5$')
y = AFa*(np.abs(x)**2.0);      plt.plot(x, y, color='tab:red',lw=2, label=r'$n=2$')
plt.grid(); plt.legend(loc='upper center', fontsize=12);

# %% [markdown]
# ## Hyperbolic functions
# * $\cosh x = \frac{e^x + e^{-x}}{2}$
#
# * $\sinh x = \frac{e^x - e^{-x}}{2}$
#
# * $\tanh x = \frac{e^x - e^{-x}}{e^x + e^{-x}}$

# %%
x = np.linspace(-5*np.pi, 5*np.pi)

y = 0.5*(np.exp(x) + np.exp(-x))

plt.plot(x, y)
plt.plot(x, np.cosh(x), '--')

# %%
x = np.linspace(-5*np.pi, 5*np.pi)

y = 0.5*(np.exp(x) - np.exp(-x))

plt.plot(x, y)
plt.plot(x, np.sinh(x), '--')

# %%
x = np.linspace(-5*np.pi, 5*np.pi)

y = (np.exp(x) - np.exp(-x))/((np.exp(x) + np.exp(-x)))

plt.plot(x, y)
plt.plot(x, np.tanh(x), '--')

# %%
plt.plot(x, y , label='Potential')
plt.plot(x, -1+np.tanh(x)**2, '--', label='Force')
plt.legend()

# %% [markdown]
# ## Phase diagrams

# %% [markdown]
# ### Simple harmonic oscillator
#
#
# $U(x)=\frac12 K x^2$.
#
# The coorespodning force is $F(x)= - U'(x)=-Kx$
#
# The expresion for energy is
#
# $E = \frac12 m \dot x^2 + \frac12 K x^2$
#
# This implies that:
#
# $\dot x = \sqrt{2(E- U)/m}$

# %%
Lx, Ly = 2*np.pi, 2*np.pi
Np = 32
xG, xdotG = np.meshgrid(np.linspace(-Lx, Lx, Np), np.linspace(-Lx, Lx, Np))

xddotG = -xG

plt.streamplot(xG, xdotG, xdotG, xddotG)

# %% [markdown]
# ### Inverted parabola
#
#
# $U(x)=-\frac12 K x^2$.
#
# The coorespodning force is $F(x)= - U'(x)=Kx$
#
# The expresion for energy is
#
# $E = \frac12 m \dot x^2 - \frac12 K x^2$
#
# This implies that:
#
# $\dot x = \sqrt{2(E- U)/m}$

# %%
Lx, Ly = 2*np.pi, 2*np.pi
Np = 32
xG, xdotG = np.meshgrid(np.linspace(-Lx, Lx, Np), np.linspace(-Lx, Lx, Np))

xddotG = xG

plt.streamplot(xG, xdotG, xdotG, xddotG)

# %% [markdown]
# ### Plane pendulum
#
# $U(x)=2mgl\sin^2 (x/2)$.
#
# The coorespodning force is $F(x)= - U'(x)=-mgl\sin(x)$
#
# The expresion for energy is
#
# $E = \frac12 m \dot x^2 + 2mgl\sin\theta$
#
# This implies that:
#
# $\dot x = \sqrt{2(E- U)/m}$

# %%
Lx, Ly = 3*np.pi, 1.2*np.pi
Np = 32
xG, xdotG = np.meshgrid(np.linspace(-Lx, Lx, Np), np.linspace(-Ly, Ly, Np))

xddotG = -np.sin(xG)

plt.streamplot(xG, xdotG, xdotG, xddotG)

# %% [markdown]
# ## Consider motion in a potential
#
# $U(x)=\tanh (x)$.
#
# The coorespodning force is $F(x)= - U'(x)=\tanh^2 (x)-1$

# %%
Lx, Ly = np.pi, np.pi
Np = 32
xG, xdotG = np.meshgrid(np.linspace(-Lx, Lx, Np), np.linspace(-Ly, Ly, Np))

xddotG = np.tanh(xG)**2 -1

plt.streamplot(xG, xdotG, xdotG, xddotG)

# %% [markdown]
# ### Computing derivatives using sympy

# %%
from sympy import *

# %%
x, y, z = symbols('x y z')
init_printing(use_unicode=True)

# %%
diff(cos(x), x)
# Out:
# -sin(x)

# %%
diff(sin(x), x)
# Out:
# cos(x)

# %%
diff(tan(x), x)
# Out:
#    2
# tan (x) + 1

# %%
diff(tanh(x), x)
# Out:
#         2
# 1 - tanh (x)

# %%
diff(diff(tanh(x), x), x)
# Out:
#  ⎛          2   ⎞
# -⎝2 - 2⋅tanh (x)⎠⋅tanh(x)

# %%
 from IPython.display import HTML

HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/rB83DpBJQsE?rel=0&amp;controls=0&amp;showinfo=0" frameborder="0" allowfullscreen></iframe>')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/display.py:701: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="560" height="315" src="https://www.youtube.com/embed/rB83DpBJQsE?rel=0&amp;controls=0&amp;showinfo=0" frameborder="0" allowfullscreen></iframe>
